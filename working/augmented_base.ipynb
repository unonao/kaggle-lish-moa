# %% [markdown]
# # base 1d cnn model

# %%
EPOCHS = 25
BATCH_SIZE = 128
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-5
NFOLDS = 5
EARLY_STOPPING_STEPS = 10
EARLY_STOP = False
SEED = [0, 1, 2, 3 ,4, 5]

# %%
#ColaboratoryかKaggleNotebookか判別
import sys
import os
from pathlib import Path

if 'google.colab' in sys.modules:  # colab環境
    SEED = [0] # 1つ目のみ
    INPUT = Path('/content/input/')

    # drive mount
    from google.colab import drive
    drive.mount('/content/drive/')

    # working dir に移動
    os.chdir('/content/drive/MyDrive/git/kaggle-lish-moa/working')
    print("cwd:", os.getcwd())
    # !pip install iterative-stratification

elif 'kaggle_web_client' in sys.modules:  # kaggle環境
    INPUT = Path('../input/')
    sys.path.append('../input/iterative-stratification/iterative-stratification-master')

from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# Out:
# Mounted at /content/drive/
# cwd: /content/drive/MyDrive/git/kaggle-lish-moa/working
# Collecting iterative-stratification
#   Downloading https://files.pythonhosted.org/packages/9d/79/9ba64c8c07b07b8b45d80725b2ebd7b7884701c1da34f70d4749f7b45f9a/iterative_stratification-0.1.6-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from iterative-stratification) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->iterative-stratification) (1.0.1)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.6

# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import os
import copy
import seaborn as sns

from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import warnings
warnings.filterwarnings('ignore')

# %%
os.listdir('../input/lish-moa')
# Out:
# ['train_drug.csv',
#  'test_features.csv',
#  'train_targets_scored.csv',
#  'train_targets_nonscored.csv',
#  'train_features.csv',
#  'sample_submission.csv']

# %%
train_features = pd.read_csv('../input/lish-moa/train_features.csv')
train_targets_scored = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
train_targets_nonscored = pd.read_csv('../input/lish-moa/train_targets_nonscored.csv')

test_features = pd.read_csv('../input/lish-moa/test_features.csv')
sample_submission = pd.read_csv('../input/lish-moa/sample_submission.csv')

# %%
GENES = [col for col in train_features.columns if col.startswith('g-')]
CELLS = [col for col in train_features.columns if col.startswith('c-')]

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(seed=42)

# %%
train_targets_scored.sum()[1:].sort_values()
# Out:
# atp-sensitive_potassium_channel_antagonist      1
# erbb2_inhibitor                                 1
# diuretic                                        6
# autotaxin_inhibitor                             6
# protein_phosphatase_inhibitor                   6
#                                              ...
# serotonin_receptor_antagonist                 404
# dopamine_receptor_antagonist                  424
# cyclooxygenase_inhibitor                      435
# proteasome_inhibitor                          726
# nfkb_inhibitor                                832
# Length: 206, dtype: object

# %%
train_features['cp_type'].unique()
# Out:
# array(['trt_cp', 'ctl_vehicle'], dtype=object)

# %% [markdown]
# # PCA features + Existing features

# %%
# GENES
n_comp = 50

data = pd.concat([pd.DataFrame(train_features[GENES]), pd.DataFrame(test_features[GENES])])
data2 = (PCA(n_components=n_comp, random_state=42).fit_transform(data[GENES]))
train2 = data2[:train_features.shape[0]]; test2 = data2[-test_features.shape[0]:]

train2 = pd.DataFrame(train2, columns=[f'pca_G-{i}' for i in range(n_comp)])
test2 = pd.DataFrame(test2, columns=[f'pca_G-{i}' for i in range(n_comp)])

# drop_cols = [f'c-{i}' for i in range(n_comp,len(GENES))]
train_features = pd.concat((train_features, train2), axis=1)
test_features = pd.concat((test_features, test2), axis=1)

# %%
#CELLS
n_comp = 15

data = pd.concat([pd.DataFrame(train_features[CELLS]), pd.DataFrame(test_features[CELLS])])
data2 = (PCA(n_components=n_comp, random_state=42).fit_transform(data[CELLS]))
train2 = data2[:train_features.shape[0]]; test2 = data2[-test_features.shape[0]:]

train2 = pd.DataFrame(train2, columns=[f'pca_C-{i}' for i in range(n_comp)])
test2 = pd.DataFrame(test2, columns=[f'pca_C-{i}' for i in range(n_comp)])

# drop_cols = [f'c-{i}' for i in range(n_comp,len(CELLS))]
train_features = pd.concat((train_features, train2), axis=1)
test_features = pd.concat((test_features, test2), axis=1)

# %% [markdown]
# # feature Selection using Variance Encoding

# %%
from sklearn.feature_selection import VarianceThreshold


var_thresh = VarianceThreshold(threshold=0.5)
data = train_features.append(test_features)
data_transformed = var_thresh.fit_transform(data.iloc[:, 4:])

train_features_transformed = data_transformed[ : train_features.shape[0]]
test_features_transformed = data_transformed[-test_features.shape[0] : ]


train_features = pd.DataFrame(train_features[['sig_id','cp_type','cp_time','cp_dose']].values.reshape(-1, 4),\
                              columns=['sig_id','cp_type','cp_time','cp_dose'])

train_features = pd.concat([train_features, pd.DataFrame(train_features_transformed)], axis=1)


test_features = pd.DataFrame(test_features[['sig_id','cp_type','cp_time','cp_dose']].values.reshape(-1, 4),\
                             columns=['sig_id','cp_type','cp_time','cp_dose'])

test_features = pd.concat([test_features, pd.DataFrame(test_features_transformed)], axis=1)

train_features
# Out:
#              sig_id      cp_type cp_time  ...       924       925       926
# 0      id_000644bb2       trt_cp      24  ... -0.615139  0.174407  0.082941
# 1      id_000779bfc       trt_cp      72  ...  0.669397  0.447651  1.207365
# 2      id_000a6266a       trt_cp      48  ...  0.572233 -0.261651 -0.638141
# 3      id_0015fd391       trt_cp      48  ...  0.689218 -1.433683  1.323147
# 4      id_001626bd3       trt_cp      72  ...  0.350304 -0.326626 -0.344389
# ...             ...          ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed       trt_cp      24  ...  0.173586 -0.611718  1.607084
# 23810  id_fffb70c0c       trt_cp      24  ... -0.219500  0.377156  0.555680
# 23811  id_fffc1c3f4  ctl_vehicle      48  ...  0.331622 -0.006669  0.081750
# 23812  id_fffcb9e7c       trt_cp      24  ... -0.531532 -0.351892  0.542268
# 23813  id_ffffdd77b       trt_cp      72  ...  3.509945  1.710206 -2.434251
#
# [23814 rows x 931 columns]

# %%
train = train_features.merge(train_targets_scored, on='sig_id')
train = train.merge(train_targets_nonscored_high_corr, on='sig_id')

train = train[train['cp_type']!='ctl_vehicle'].reset_index(drop=True)
test = test_features[test_features['cp_type']!='ctl_vehicle'].reset_index(drop=True)

#----
# augmentation for less target
skew_target_cols = train_targets_scored.drop('sig_id', axis=1).sum()[lambda x:x<10].index.values
print(skew_target_cols)
augmented_num = 0
for col in skew_target_cols:
    tmp_df = train[train[col]==1].copy()
for _ in range(4):
    train = pd.concat((train, tmp_df))
    augmented_num += len(tmp_df.index) * 4
print(train.shape)
train = train.reset_index(drop=True)
#---
target = train[train_targets_scored.columns]
# Out:
# ['aldehyde_dehydrogenase_inhibitor' 'antiarrhythmic'
#  'atm_kinase_inhibitor' 'atp-sensitive_potassium_channel_antagonist'
#  'autotaxin_inhibitor' 'bacterial_membrane_integrity_inhibitor'
#  'calcineurin_inhibitor' 'coagulation_factor_inhibitor' 'diuretic'
#  'elastase_inhibitor' 'erbb2_inhibitor' 'laxative' 'leukotriene_inhibitor'
#  'lxr_agonist' 'nicotinic_receptor_agonist'
#  'norepinephrine_reuptake_inhibitor' 'protein_phosphatase_inhibitor'
#  'retinoid_receptor_antagonist' 'steroid' 'tlr_antagonist'
#  'tropomyosin_receptor_kinase_inhibitor'
#  'ubiquitin_specific_protease_inhibitor']
# (21972, 1137)

# %%
train = train.drop('cp_type', axis=1)
test = test.drop('cp_type', axis=1)

# %%
train
# Out:
#              sig_id cp_time  ... vitamin_d_receptor_agonist  wnt_inhibitor
# 0      id_000644bb2      24  ...                          0              0
# 1      id_000779bfc      72  ...                          0              0
# 2      id_000a6266a      48  ...                          0              0
# 3      id_0015fd391      48  ...                          0              0
# 4      id_001626bd3      72  ...                          0              0
# ...             ...     ...  ...                        ...            ...
# 21967  id_2c1f61f65      72  ...                          0              0
# 21968  id_311b47f39      24  ...                          0              0
# 21969  id_452abbea4      72  ...                          0              0
# 21970  id_5c8f28f62      48  ...                          0              0
# 21971  id_908187a04      24  ...                          0              0
#
# [21972 rows x 1136 columns]

# %%
target_cols = target.drop('sig_id', axis=1).columns.values.tolist()

# %% [markdown]
# # CV folds

# %%
folds = train.copy()

mskf = MultilabelStratifiedKFold(n_splits=5)

for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=target)):
    folds.loc[v_idx, 'kfold'] = int(f)

folds['kfold'] = folds['kfold'].astype(int)
folds
# Out:
#              sig_id cp_time  ... wnt_inhibitor  kfold
# 0      id_000644bb2      24  ...             0      1
# 1      id_000779bfc      72  ...             0      1
# 2      id_000a6266a      48  ...             0      4
# 3      id_0015fd391      48  ...             0      1
# 4      id_001626bd3      72  ...             0      3
# ...             ...     ...  ...           ...    ...
# 21967  id_2c1f61f65      72  ...             0      1
# 21968  id_311b47f39      24  ...             0      4
# 21969  id_452abbea4      72  ...             0      0
# 21970  id_5c8f28f62      48  ...             0      2
# 21971  id_908187a04      24  ...             0      3
#
# [21972 rows x 1137 columns]

# %%
print(train.shape)
print(folds.shape)
print(test.shape)
print(target.shape)
print(sample_submission.shape)
# Out:
# (21972, 1136)
# (21972, 1137)
# (3624, 930)
# (21972, 207)
# (3982, 207)

# %% [markdown]
# # Dataset Classes

# %%
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct

# %%
def train_fn(model, optimizer, scheduler, loss_fn, dataloader, device):
    model.train()
    final_loss = 0
    
    for data in dataloader:
        optimizer.zero_grad()
        inputs, targets = data['x'].to(device), data['y'].to(device)
#         print(inputs.shape)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        final_loss += loss.item()
        
    final_loss /= len(dataloader)
    
    return final_loss


def valid_fn(model, loss_fn, dataloader, device):
    model.eval()
    final_loss = 0
    valid_preds = []
    
    for data in dataloader:
        inputs, targets = data['x'].to(device), data['y'].to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        
        final_loss += loss.item()
        valid_preds.append(outputs.sigmoid().detach().cpu().numpy())
        
    final_loss /= len(dataloader)
    valid_preds = np.concatenate(valid_preds)
    
    return final_loss, valid_preds

def inference_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs)
        
        preds.append(outputs.sigmoid().detach().cpu().numpy())
        
    preds = np.concatenate(preds)
    
    return preds

# %% [markdown]
# # Model

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size):
        super(Model, self).__init__()
        cha_1 = 256
        cha_2 = 512
        cha_3 = 512

        cha_1_reshape = int(hidden_size/cha_1)
        cha_po_1 = int(hidden_size/cha_1/2)
        cha_po_2 = int(hidden_size/cha_1/2/2) * cha_3

        self.cha_1 = cha_1
        self.cha_2 = cha_2
        self.cha_3 = cha_3
        self.cha_1_reshape = cha_1_reshape
        self.cha_po_1 = cha_po_1
        self.cha_po_2 = cha_po_2

        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))

        self.batch_norm_c1 = nn.BatchNorm1d(cha_1)
        self.dropout_c1 = nn.Dropout(0.1)
        self.conv1 = nn.utils.weight_norm(nn.Conv1d(cha_1,cha_2, kernel_size = 5, stride = 1, padding=2,  bias=False),dim=None)

        self.ave_po_c1 = nn.AdaptiveAvgPool1d(output_size = cha_po_1)

        self.batch_norm_c2 = nn.BatchNorm1d(cha_2)
        self.dropout_c2 = nn.Dropout(0.1)
        self.conv2 = nn.utils.weight_norm(nn.Conv1d(cha_2,cha_2, kernel_size = 3, stride = 1, padding=1, bias=True),dim=None)

        self.batch_norm_c2_1 = nn.BatchNorm1d(cha_2)
        self.dropout_c2_1 = nn.Dropout(0.3)
        self.conv2_1 = nn.utils.weight_norm(nn.Conv1d(cha_2,cha_2, kernel_size = 3, stride = 1, padding=1, bias=True),dim=None)

        self.batch_norm_c2_2 = nn.BatchNorm1d(cha_2)
        self.dropout_c2_2 = nn.Dropout(0.2)
        self.conv2_2 = nn.utils.weight_norm(nn.Conv1d(cha_2,cha_3, kernel_size = 5, stride = 1, padding=2, bias=True),dim=None)

        self.max_po_c2 = nn.MaxPool1d(kernel_size=4, stride=2, padding=1)

        self.flt = nn.Flatten()

        self.batch_norm3 = nn.BatchNorm1d(cha_po_2)
        self.dropout3 = nn.Dropout(0.2)
        self.dense3 = nn.utils.weight_norm(nn.Linear(cha_po_2, num_targets))

    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.celu(self.dense1(x), alpha=0.06)

        x = x.reshape(x.shape[0],self.cha_1,self.cha_1_reshape)

        x = self.batch_norm_c1(x)
        x = self.dropout_c1(x)
        x = F.relu(self.conv1(x))

        x = self.ave_po_c1(x)

        x = self.batch_norm_c2(x)
        x = self.dropout_c2(x)
        x = F.relu(self.conv2(x))
        x_s = x

        x = self.batch_norm_c2_1(x)
        x = self.dropout_c2_1(x)
        x = F.relu(self.conv2_1(x))

        x = self.batch_norm_c2_2(x)
        x = self.dropout_c2_2(x)
        x = F.relu(self.conv2_2(x))
        x =  x * x_s

        x = self.max_po_c2(x)

        x = self.flt(x)

        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)

        return x

# %% [markdown]
# # Preprocessing steps

# %%
def process_data(data):
    
    data = pd.get_dummies(data, columns=['cp_time','cp_dose'])
    
    return data

# %%
feature_cols = [c for c in process_data(folds).columns if c not in target_cols]
feature_cols = [c for c in feature_cols if c not in ['kfold','sig_id']]
len(feature_cols)
# Out:
# 932

# %%
# HyperParameters

DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')

num_features=len(feature_cols)
num_targets=len(target_cols)
hidden_size=4096

# %% [markdown]
# # Single fold training

# %%
def run_training(fold, seed):
    
    seed_everything(seed)
    
    train = process_data(folds)
    test_ = process_data(test)
    
    trn_idx = train[train['kfold'] != fold].index
    val_idx = train[train['kfold'] == fold].index
    
    train_df = train[train['kfold'] != fold].reset_index(drop=True)
    valid_df = train[train['kfold'] == fold].reset_index(drop=True)
    
    x_train, y_train  = train_df[feature_cols].values, train_df[target_cols].values
    x_valid, y_valid =  valid_df[feature_cols].values, valid_df[target_cols].values
    
    train_dataset = MoADataset(x_train, y_train)
    valid_dataset = MoADataset(x_valid, y_valid)
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = Model(
        num_features=num_features,
        num_targets=num_targets,
        hidden_size=hidden_size,
    )
    
    model.to(DEVICE)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=EPOCHS, steps_per_epoch=len(trainloader))
    
    loss_fn = nn.BCEWithLogitsLoss()
    
    early_stopping_steps = EARLY_STOPPING_STEPS
    early_step = 0
    
    oof = np.zeros((len(train), target.iloc[:, 1:].shape[1]))
    best_loss = np.inf
    
    for epoch in range(EPOCHS):
        
        train_loss = train_fn(model, optimizer, scheduler, loss_fn, trainloader, DEVICE)
        print(f"FOLD: {fold}, EPOCH: {epoch}, train_loss: {train_loss}")
        valid_loss, valid_preds = valid_fn(model, loss_fn, validloader, DEVICE)
        print(f"FOLD: {fold}, EPOCH: {epoch}, valid_loss: {valid_loss}")
        
        if valid_loss < best_loss:
            
            best_loss = valid_loss
            oof[val_idx] = valid_preds
            torch.save(model.state_dict(), f"FOLD{fold}_.pth")
        
        elif(EARLY_STOP == True):
            
            early_step += 1
            if (early_step >= early_stopping_steps):
                break
            
    
    #--------------------- PREDICTION---------------------
    x_test = test_[feature_cols].values
    testdataset = TestDataset(x_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = Model(
        num_features=num_features,
        num_targets=num_targets,
        hidden_size=hidden_size,
    )
    
    model.load_state_dict(torch.load(f"FOLD{fold}_.pth"))
    model.to(DEVICE)
    
    predictions = np.zeros((len(test_), target.iloc[:, 1:].shape[1]))
    predictions = inference_fn(model, testloader, DEVICE)
    
    return oof, predictions

# %%
def run_k_fold(NFOLDS, seed):
    oof = np.zeros((len(train), len(target_cols)))
    predictions = np.zeros((len(test), len(target_cols)))
    
    for fold in range(NFOLDS):
        oof_, pred_ = run_training(fold, seed)
        
        predictions += pred_ / NFOLDS
        oof += oof_
        
    return oof, predictions

# %%
# Averaging on multiple SEEDS


oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

for seed in SEED:
    
    oof_, predictions_ = run_k_fold(NFOLDS, seed)
    oof += oof_ / len(SEED)
    predictions += predictions_ / len(SEED)

train[target_cols] = oof
test[target_cols] = predictions
# Out:
# FOLD: 0, EPOCH: 0, train_loss: 0.46664734416897746
# FOLD: 0, EPOCH: 0, valid_loss: 0.02336036025413445
# FOLD: 0, EPOCH: 1, train_loss: 0.020412403482781803
# FOLD: 0, EPOCH: 1, valid_loss: 0.018696545330541475
# FOLD: 0, EPOCH: 2, train_loss: 0.018316618288340775
# FOLD: 0, EPOCH: 2, valid_loss: 0.01737671739288739
# FOLD: 0, EPOCH: 3, train_loss: 0.017456121702233086
# FOLD: 0, EPOCH: 3, valid_loss: 0.018070593689169204
# FOLD: 0, EPOCH: 4, train_loss: 0.0172131575603524
# FOLD: 0, EPOCH: 4, valid_loss: 0.01706525749926056
# FOLD: 0, EPOCH: 5, train_loss: 0.017002045338892418
# FOLD: 0, EPOCH: 5, valid_loss: 0.017133581079542638
# FOLD: 0, EPOCH: 6, train_loss: 0.017118275597475578
# FOLD: 0, EPOCH: 6, valid_loss: 0.017362533616168158
# FOLD: 0, EPOCH: 7, train_loss: 0.017020650423955227
# FOLD: 0, EPOCH: 7, valid_loss: 0.017155231801526886
# FOLD: 0, EPOCH: 8, train_loss: 0.017017787140186712
# FOLD: 0, EPOCH: 8, valid_loss: 0.017184632032045295
# FOLD: 0, EPOCH: 9, train_loss: 0.016944043776965227
# FOLD: 0, EPOCH: 9, valid_loss: 0.017290191086275237
# FOLD: 0, EPOCH: 10, train_loss: 0.01692091279487679
# FOLD: 0, EPOCH: 10, valid_loss: 0.01714269548122372
# FOLD: 0, EPOCH: 11, train_loss: 0.016880979322814856
# FOLD: 0, EPOCH: 11, valid_loss: 0.016975505304123673
# FOLD: 0, EPOCH: 12, train_loss: 0.016833329856719658
# FOLD: 0, EPOCH: 12, valid_loss: 0.01702906561217138
# FOLD: 0, EPOCH: 13, train_loss: 0.016672895829854668
# FOLD: 0, EPOCH: 13, valid_loss: 0.01671738957187959
# FOLD: 0, EPOCH: 14, train_loss: 0.016487094364466444
# FOLD: 0, EPOCH: 14, valid_loss: 0.016729212126561574
# FOLD: 0, EPOCH: 15, train_loss: 0.016316336525631123
# FOLD: 0, EPOCH: 15, valid_loss: 0.016433537911091534
# FOLD: 0, EPOCH: 16, train_loss: 0.016112940068748118
# FOLD: 0, EPOCH: 16, valid_loss: 0.01633057820477656
# FOLD: 0, EPOCH: 17, train_loss: 0.015815464597519324
# FOLD: 0, EPOCH: 17, valid_loss: 0.01612054676349674
# FOLD: 0, EPOCH: 18, train_loss: 0.015574293042384628
# FOLD: 0, EPOCH: 18, valid_loss: 0.01608455569616386
# FOLD: 0, EPOCH: 19, train_loss: 0.01507681551510873
# FOLD: 0, EPOCH: 19, valid_loss: 0.015775448908763274
# FOLD: 0, EPOCH: 20, train_loss: 0.014552916663334421
# FOLD: 0, EPOCH: 20, valid_loss: 0.015891884533422333
# FOLD: 0, EPOCH: 21, train_loss: 0.014078845701895762
# FOLD: 0, EPOCH: 21, valid_loss: 0.015573714886392866
# FOLD: 0, EPOCH: 22, train_loss: 0.013482040691904831
# FOLD: 0, EPOCH: 22, valid_loss: 0.015558844112924167
# FOLD: 0, EPOCH: 23, train_loss: 0.012986564414872639
# FOLD: 0, EPOCH: 23, valid_loss: 0.015533680548625334
# FOLD: 0, EPOCH: 24, train_loss: 0.01271287023184308
# FOLD: 0, EPOCH: 24, valid_loss: 0.01553042810410261
# FOLD: 1, EPOCH: 0, train_loss: 0.4678592424083879
# FOLD: 1, EPOCH: 0, valid_loss: 0.02375936886029584
# FOLD: 1, EPOCH: 1, train_loss: 0.020688913303656853
# FOLD: 1, EPOCH: 1, valid_loss: 0.019463101934109415
# FOLD: 1, EPOCH: 2, train_loss: 0.018484777527982773
# FOLD: 1, EPOCH: 2, valid_loss: 0.017595914990774224
# FOLD: 1, EPOCH: 3, train_loss: 0.017609242963996054
# FOLD: 1, EPOCH: 3, valid_loss: 0.017481220673237527
# FOLD: 1, EPOCH: 4, train_loss: 0.017207558570510668
# FOLD: 1, EPOCH: 4, valid_loss: 0.01779270555291857
# FOLD: 1, EPOCH: 5, train_loss: 0.017057186572987965
# FOLD: 1, EPOCH: 5, valid_loss: 0.017175146963979517
# FOLD: 1, EPOCH: 6, train_loss: 0.01704779000736881
# FOLD: 1, EPOCH: 6, valid_loss: 0.017326964145260196
# FOLD: 1, EPOCH: 7, train_loss: 0.016987768116582563
# FOLD: 1, EPOCH: 7, valid_loss: 0.01693317483046225
# FOLD: 1, EPOCH: 8, train_loss: 0.017004023832471474
# FOLD: 1, EPOCH: 8, valid_loss: 0.018683013319969178
# FOLD: 1, EPOCH: 9, train_loss: 0.017055969287141943
# FOLD: 1, EPOCH: 9, valid_loss: 0.016973678208887576
# FOLD: 1, EPOCH: 10, train_loss: 0.016862524389896705
# FOLD: 1, EPOCH: 10, valid_loss: 0.016878035185592517
# FOLD: 1, EPOCH: 11, train_loss: 0.01681646881490082
# FOLD: 1, EPOCH: 11, valid_loss: 0.01757836022547313
# FOLD: 1, EPOCH: 12, train_loss: 0.016728847429318273
# FOLD: 1, EPOCH: 12, valid_loss: 0.016945864499679632
# FOLD: 1, EPOCH: 13, train_loss: 0.016600204314496637
# FOLD: 1, EPOCH: 13, valid_loss: 0.016664151767534868
# FOLD: 1, EPOCH: 14, train_loss: 0.016467677314590284
# FOLD: 1, EPOCH: 14, valid_loss: 0.016959264262446334
# FOLD: 1, EPOCH: 15, train_loss: 0.016315855045357475
# FOLD: 1, EPOCH: 15, valid_loss: 0.016369575155632837
# FOLD: 1, EPOCH: 16, train_loss: 0.015986836596351604
# FOLD: 1, EPOCH: 16, valid_loss: 0.016311142380748475
# FOLD: 1, EPOCH: 17, train_loss: 0.015750224000193935
# FOLD: 1, EPOCH: 17, valid_loss: 0.01625641520534243
# FOLD: 1, EPOCH: 18, train_loss: 0.015450239498708128
# FOLD: 1, EPOCH: 18, valid_loss: 0.015992284273462637
# FOLD: 1, EPOCH: 19, train_loss: 0.015050125807739687
# FOLD: 1, EPOCH: 19, valid_loss: 0.01580338039036308
# FOLD: 1, EPOCH: 20, train_loss: 0.014618504610236572
# FOLD: 1, EPOCH: 20, valid_loss: 0.01572438534349203
# FOLD: 1, EPOCH: 21, train_loss: 0.013994617995036684
# FOLD: 1, EPOCH: 21, valid_loss: 0.015622606793684619
# FOLD: 1, EPOCH: 22, train_loss: 0.013413329811199852
# FOLD: 1, EPOCH: 22, valid_loss: 0.015494976671678679
# FOLD: 1, EPOCH: 23, train_loss: 0.012969440686098043
# FOLD: 1, EPOCH: 23, valid_loss: 0.01545620041766337
# FOLD: 1, EPOCH: 24, train_loss: 0.012712849594274725
# FOLD: 1, EPOCH: 24, valid_loss: 0.015440698633236544
# FOLD: 2, EPOCH: 0, train_loss: 0.46704140499882074
# FOLD: 2, EPOCH: 0, valid_loss: 0.02405275436384337
# FOLD: 2, EPOCH: 1, train_loss: 0.02071541298072839
# FOLD: 2, EPOCH: 1, valid_loss: 0.01891558138387544
# FOLD: 2, EPOCH: 2, train_loss: 0.018644728184934112
# FOLD: 2, EPOCH: 2, valid_loss: 0.01784363423607179
# FOLD: 2, EPOCH: 3, train_loss: 0.017371919674231955
# FOLD: 2, EPOCH: 3, valid_loss: 0.017535590140947275
# FOLD: 2, EPOCH: 4, train_loss: 0.01713427126515603
# FOLD: 2, EPOCH: 4, valid_loss: 0.018168564859245506
# FOLD: 2, EPOCH: 5, train_loss: 0.01696881564145071
# FOLD: 2, EPOCH: 5, valid_loss: 0.018342923532639232
# FOLD: 2, EPOCH: 6, train_loss: 0.01697001292410752
# FOLD: 2, EPOCH: 6, valid_loss: 0.017528952551739557
# FOLD: 2, EPOCH: 7, train_loss: 0.016921335223900234
# FOLD: 2, EPOCH: 7, valid_loss: 0.017679208942822048
# FOLD: 2, EPOCH: 8, train_loss: 0.016967953911618046
# FOLD: 2, EPOCH: 8, valid_loss: 0.017245284281671047
# FOLD: 2, EPOCH: 9, train_loss: 0.016900446529135756
# FOLD: 2, EPOCH: 9, valid_loss: 0.017159840810511792
# FOLD: 2, EPOCH: 10, train_loss: 0.01684565126787925
# FOLD: 2, EPOCH: 10, valid_loss: 0.01716192236968449
# FOLD: 2, EPOCH: 11, train_loss: 0.016801409639310146
# FOLD: 2, EPOCH: 11, valid_loss: 0.016847181293581214
# FOLD: 2, EPOCH: 12, train_loss: 0.01670116657877098
# FOLD: 2, EPOCH: 12, valid_loss: 0.01696264733161245
# FOLD: 2, EPOCH: 13, train_loss: 0.016531083172700113
# FOLD: 2, EPOCH: 13, valid_loss: 0.017018334354673113
# FOLD: 2, EPOCH: 14, train_loss: 0.01640013446086559
# FOLD: 2, EPOCH: 14, valid_loss: 0.016878941814814294
# FOLD: 2, EPOCH: 15, train_loss: 0.01621609075885752
# FOLD: 2, EPOCH: 15, valid_loss: 0.016635314348552907
# FOLD: 2, EPOCH: 16, train_loss: 0.016015805850696306
# FOLD: 2, EPOCH: 16, valid_loss: 0.016498751219894206
# FOLD: 2, EPOCH: 17, train_loss: 0.01574956196481767
# FOLD: 2, EPOCH: 17, valid_loss: 0.016302606543259962
# FOLD: 2, EPOCH: 18, train_loss: 0.01547881383853762
# FOLD: 2, EPOCH: 18, valid_loss: 0.01607607802642243
# FOLD: 2, EPOCH: 19, train_loss: 0.015035305860573831
# FOLD: 2, EPOCH: 19, valid_loss: 0.0160286882892251
# FOLD: 2, EPOCH: 20, train_loss: 0.01460633883792637
# FOLD: 2, EPOCH: 20, valid_loss: 0.015839818040175098
# FOLD: 2, EPOCH: 21, train_loss: 0.013988168950638046
# FOLD: 2, EPOCH: 21, valid_loss: 0.015721528258706843
# FOLD: 2, EPOCH: 22, train_loss: 0.01343358512562902
# FOLD: 2, EPOCH: 22, valid_loss: 0.015692195722035
# FOLD: 2, EPOCH: 23, train_loss: 0.012969916099277527
# FOLD: 2, EPOCH: 23, valid_loss: 0.015642597100564412
# FOLD: 2, EPOCH: 24, train_loss: 0.012716171149488377
# FOLD: 2, EPOCH: 24, valid_loss: 0.015643829878951823
# FOLD: 3, EPOCH: 0, train_loss: 0.46785052652484266
# FOLD: 3, EPOCH: 0, valid_loss: 0.02474397197365761
# FOLD: 3, EPOCH: 1, train_loss: 0.020495814365753227
# FOLD: 3, EPOCH: 1, valid_loss: 0.01877185409622533
# FOLD: 3, EPOCH: 2, train_loss: 0.018238852380950382
# FOLD: 3, EPOCH: 2, valid_loss: 0.017799085857612747
# FOLD: 3, EPOCH: 3, train_loss: 0.01747094254022923
# FOLD: 3, EPOCH: 3, valid_loss: 0.017879862657615115
# FOLD: 3, EPOCH: 4, train_loss: 0.017170120125123554
# FOLD: 3, EPOCH: 4, valid_loss: 0.017591253401977675
# FOLD: 3, EPOCH: 5, train_loss: 0.01698949494385633
# FOLD: 3, EPOCH: 5, valid_loss: 0.017608412435012204
# FOLD: 3, EPOCH: 6, train_loss: 0.016909531074697556
# FOLD: 3, EPOCH: 6, valid_loss: 0.017314745831702436
# FOLD: 3, EPOCH: 7, train_loss: 0.016933896106438362
# FOLD: 3, EPOCH: 7, valid_loss: 0.017335893559668747
# FOLD: 3, EPOCH: 8, train_loss: 0.016887193383729977
# FOLD: 3, EPOCH: 8, valid_loss: 0.01771790614085538
# FOLD: 3, EPOCH: 9, train_loss: 0.01693387082575456
# FOLD: 3, EPOCH: 9, valid_loss: 0.0169994626726423
# FOLD: 3, EPOCH: 10, train_loss: 0.016853747632948383
# FOLD: 3, EPOCH: 10, valid_loss: 0.01709179598838091
# FOLD: 3, EPOCH: 11, train_loss: 0.016753652747180582
# FOLD: 3, EPOCH: 11, valid_loss: 0.01734948626586369
# FOLD: 3, EPOCH: 12, train_loss: 0.01672085434657292
# FOLD: 3, EPOCH: 12, valid_loss: 0.017062740427042755
# FOLD: 3, EPOCH: 13, train_loss: 0.016511569251778765
# FOLD: 3, EPOCH: 13, valid_loss: 0.01700121161660978
# FOLD: 3, EPOCH: 14, train_loss: 0.01639481905199911
# FOLD: 3, EPOCH: 14, valid_loss: 0.016764183289238385
# FOLD: 3, EPOCH: 15, train_loss: 0.01628901074518976
# FOLD: 3, EPOCH: 15, valid_loss: 0.016758906841278075
# FOLD: 3, EPOCH: 16, train_loss: 0.015967512456025335
# FOLD: 3, EPOCH: 16, valid_loss: 0.016447603702545166
# FOLD: 3, EPOCH: 17, train_loss: 0.015783001911704956
# FOLD: 3, EPOCH: 17, valid_loss: 0.01633342472570283
# FOLD: 3, EPOCH: 18, train_loss: 0.015497928438033316
# FOLD: 3, EPOCH: 18, valid_loss: 0.016160388184445245
# FOLD: 3, EPOCH: 19, train_loss: 0.01507863930116097
# FOLD: 3, EPOCH: 19, valid_loss: 0.01594385015113013
# FOLD: 3, EPOCH: 20, train_loss: 0.014584163089107344
# FOLD: 3, EPOCH: 20, valid_loss: 0.015906743013433047
# FOLD: 3, EPOCH: 21, train_loss: 0.014052567760581556
# FOLD: 3, EPOCH: 21, valid_loss: 0.01571107166154044
# FOLD: 3, EPOCH: 22, train_loss: 0.013472546047220627
# FOLD: 3, EPOCH: 22, valid_loss: 0.01567280547959464
# FOLD: 3, EPOCH: 23, train_loss: 0.01294598608966107
# FOLD: 3, EPOCH: 23, valid_loss: 0.015651248714753558
# FOLD: 3, EPOCH: 24, train_loss: 0.012728545996967865
# FOLD: 3, EPOCH: 24, valid_loss: 0.015618343012673515
# FOLD: 4, EPOCH: 0, train_loss: 0.4676238239432375
# FOLD: 4, EPOCH: 0, valid_loss: 0.023577371558972767
# FOLD: 4, EPOCH: 1, train_loss: 0.020426655539136
# FOLD: 4, EPOCH: 1, valid_loss: 0.0185469476506114
# FOLD: 4, EPOCH: 2, train_loss: 0.018138974412357893
# FOLD: 4, EPOCH: 2, valid_loss: 0.018743209753717696
# FOLD: 4, EPOCH: 3, train_loss: 0.017446591505321903
# FOLD: 4, EPOCH: 3, valid_loss: 0.017293324215071543
# FOLD: 4, EPOCH: 4, train_loss: 0.01698664444215272
# FOLD: 4, EPOCH: 4, valid_loss: 0.017340638621577194
# FOLD: 4, EPOCH: 5, train_loss: 0.017022612025502367
# FOLD: 4, EPOCH: 5, valid_loss: 0.017272032770727364
# FOLD: 4, EPOCH: 6, train_loss: 0.016990547014427357
# FOLD: 4, EPOCH: 6, valid_loss: 0.017771630867251326
# FOLD: 4, EPOCH: 7, train_loss: 0.01698109789656988
# FOLD: 4, EPOCH: 7, valid_loss: 0.017388420924544335
# FOLD: 4, EPOCH: 8, train_loss: 0.016830835626393124
# FOLD: 4, EPOCH: 8, valid_loss: 0.01747528612613678
# FOLD: 4, EPOCH: 9, train_loss: 0.016946482289906428
# FOLD: 4, EPOCH: 9, valid_loss: 0.01736478028552873
# FOLD: 4, EPOCH: 10, train_loss: 0.0168643516447881
# FOLD: 4, EPOCH: 10, valid_loss: 0.017111505940556528
# FOLD: 4, EPOCH: 11, train_loss: 0.01681464484663329
# FOLD: 4, EPOCH: 11, valid_loss: 0.01705146171152592
# FOLD: 4, EPOCH: 12, train_loss: 0.016691801138222218
# FOLD: 4, EPOCH: 12, valid_loss: 0.017293934151530264
# FOLD: 4, EPOCH: 13, train_loss: 0.0165320065587867
# FOLD: 4, EPOCH: 13, valid_loss: 0.016747757313506945
# FOLD: 4, EPOCH: 14, train_loss: 0.016419888791236757
# FOLD: 4, EPOCH: 14, valid_loss: 0.01735853065869638
# FOLD: 4, EPOCH: 15, train_loss: 0.01627236746413552
# FOLD: 4, EPOCH: 15, valid_loss: 0.01648013344300645
# FOLD: 4, EPOCH: 16, train_loss: 0.01604285924627945
# FOLD: 4, EPOCH: 16, valid_loss: 0.016484516859054565
# FOLD: 4, EPOCH: 17, train_loss: 0.01577260462648195
# FOLD: 4, EPOCH: 17, valid_loss: 0.016231967508792876
# FOLD: 4, EPOCH: 18, train_loss: 0.015400912781394478
# FOLD: 4, EPOCH: 18, valid_loss: 0.016104655100830964
# FOLD: 4, EPOCH: 19, train_loss: 0.015007706332033958
# FOLD: 4, EPOCH: 19, valid_loss: 0.015889528207480907
# FOLD: 4, EPOCH: 20, train_loss: 0.014508123415103857
# FOLD: 4, EPOCH: 20, valid_loss: 0.01574521293597562
# FOLD: 4, EPOCH: 21, train_loss: 0.013976986054331064
# FOLD: 4, EPOCH: 21, valid_loss: 0.01561189317809684
# FOLD: 4, EPOCH: 22, train_loss: 0.013353765483243742
# FOLD: 4, EPOCH: 22, valid_loss: 0.015511032220508371
# FOLD: 4, EPOCH: 23, train_loss: 0.012874774871043104
# FOLD: 4, EPOCH: 23, valid_loss: 0.015480457565614156
# FOLD: 4, EPOCH: 24, train_loss: 0.012583979459452456
# FOLD: 4, EPOCH: 24, valid_loss: 0.015470499119588307
# FOLD: 0, EPOCH: 0, train_loss: 0.46878494438377843
# FOLD: 0, EPOCH: 0, valid_loss: 0.0235284227345671
# FOLD: 0, EPOCH: 1, train_loss: 0.02041299821997898
# FOLD: 0, EPOCH: 1, valid_loss: 0.01824170547936644
# FOLD: 0, EPOCH: 2, train_loss: 0.01825194786289248
# FOLD: 0, EPOCH: 2, valid_loss: 0.01774876213499478
# FOLD: 0, EPOCH: 3, train_loss: 0.017376426195698805
# FOLD: 0, EPOCH: 3, valid_loss: 0.017817374957459314
# FOLD: 0, EPOCH: 4, train_loss: 0.017010984793845295
# FOLD: 0, EPOCH: 4, valid_loss: 0.0176105226789202
# FOLD: 0, EPOCH: 5, train_loss: 0.016863699880955013
# FOLD: 0, EPOCH: 5, valid_loss: 0.017810768421207157
# FOLD: 0, EPOCH: 6, train_loss: 0.016925460922167353
# FOLD: 0, EPOCH: 6, valid_loss: 0.016962031461298467
# FOLD: 0, EPOCH: 7, train_loss: 0.016909634363770052
# FOLD: 0, EPOCH: 7, valid_loss: 0.017330530578536646
# FOLD: 0, EPOCH: 8, train_loss: 0.01696260553528217
# FOLD: 0, EPOCH: 8, valid_loss: 0.0169677290267178
# FOLD: 0, EPOCH: 9, train_loss: 0.016883630447251642
# FOLD: 0, EPOCH: 9, valid_loss: 0.017399930049266134
# FOLD: 0, EPOCH: 10, train_loss: 0.016834023030663746
# FOLD: 0, EPOCH: 10, valid_loss: 0.016797950358263085
# FOLD: 0, EPOCH: 11, train_loss: 0.016753465240902227
# FOLD: 0, EPOCH: 11, valid_loss: 0.016772843817515034
# FOLD: 0, EPOCH: 12, train_loss: 0.016656069719381092
# FOLD: 0, EPOCH: 12, valid_loss: 0.017007076154862133
# FOLD: 0, EPOCH: 13, train_loss: 0.01662887538364832
# FOLD: 0, EPOCH: 13, valid_loss: 0.01663908538009439
# FOLD: 0, EPOCH: 14, train_loss: 0.016446618585968794
# FOLD: 0, EPOCH: 14, valid_loss: 0.016585598859403815
# FOLD: 0, EPOCH: 15, train_loss: 0.016229233394066494
# FOLD: 0, EPOCH: 15, valid_loss: 0.016350838941122804
# FOLD: 0, EPOCH: 16, train_loss: 0.016009583198667868
# FOLD: 0, EPOCH: 16, valid_loss: 0.01620478890836239
# FOLD: 0, EPOCH: 17, train_loss: 0.015792909341499857
# FOLD: 0, EPOCH: 17, valid_loss: 0.016126354251589092
# FOLD: 0, EPOCH: 18, train_loss: 0.01540461962070802
# FOLD: 0, EPOCH: 18, valid_loss: 0.01600229431475912
# FOLD: 0, EPOCH: 19, train_loss: 0.015015818745545719
# FOLD: 0, EPOCH: 19, valid_loss: 0.01570282464048692
# FOLD: 0, EPOCH: 20, train_loss: 0.014528330530215433
# FOLD: 0, EPOCH: 20, valid_loss: 0.015585547100220408
# FOLD: 0, EPOCH: 21, train_loss: 0.013899883484818798
# FOLD: 0, EPOCH: 21, valid_loss: 0.015563387955938066
# FOLD: 0, EPOCH: 22, train_loss: 0.013344945831467276
# FOLD: 0, EPOCH: 22, valid_loss: 0.015501929340617997
# FOLD: 0, EPOCH: 23, train_loss: 0.012830040694308886
# FOLD: 0, EPOCH: 23, valid_loss: 0.015487071073481014
# FOLD: 0, EPOCH: 24, train_loss: 0.01256445538846479
# FOLD: 0, EPOCH: 24, valid_loss: 0.015468207454042775
# FOLD: 1, EPOCH: 0, train_loss: 0.46848698359900626
# FOLD: 1, EPOCH: 0, valid_loss: 0.024386906517403467
# FOLD: 1, EPOCH: 1, train_loss: 0.020578438375631104
# FOLD: 1, EPOCH: 1, valid_loss: 0.018288481341941016
# FOLD: 1, EPOCH: 2, train_loss: 0.01828604493884073
# FOLD: 1, EPOCH: 2, valid_loss: 0.01781096016722066
# FOLD: 1, EPOCH: 3, train_loss: 0.017286389303542135
# FOLD: 1, EPOCH: 3, valid_loss: 0.017554707771965435
# FOLD: 1, EPOCH: 4, train_loss: 0.017213807218586622
# FOLD: 1, EPOCH: 4, valid_loss: 0.017315141537359784
# FOLD: 1, EPOCH: 5, train_loss: 0.017043578235999397
# FOLD: 1, EPOCH: 5, valid_loss: 0.01783643795975617
# FOLD: 1, EPOCH: 6, train_loss: 0.01712276001015435
# FOLD: 1, EPOCH: 6, valid_loss: 0.017974640375801494
# FOLD: 1, EPOCH: 7, train_loss: 0.017008259393058826
# FOLD: 1, EPOCH: 7, valid_loss: 0.016895459326250212
# FOLD: 1, EPOCH: 8, train_loss: 0.016979913868387972
# FOLD: 1, EPOCH: 8, valid_loss: 0.017096621729433537
# FOLD: 1, EPOCH: 9, train_loss: 0.016893393015893904
# FOLD: 1, EPOCH: 9, valid_loss: 0.017062356881797313
# FOLD: 1, EPOCH: 10, train_loss: 0.01690183937603581
# FOLD: 1, EPOCH: 10, valid_loss: 0.016884957466806683
# FOLD: 1, EPOCH: 11, train_loss: 0.016832302648412144
# FOLD: 1, EPOCH: 11, valid_loss: 0.016944164889199392
# FOLD: 1, EPOCH: 12, train_loss: 0.016749287098376215
# FOLD: 1, EPOCH: 12, valid_loss: 0.016658275920365537
# FOLD: 1, EPOCH: 13, train_loss: 0.016641794379962528
# FOLD: 1, EPOCH: 13, valid_loss: 0.016716536214309078
# FOLD: 1, EPOCH: 14, train_loss: 0.016516766915826694
# FOLD: 1, EPOCH: 14, valid_loss: 0.016698275400059564
# FOLD: 1, EPOCH: 15, train_loss: 0.016293818509017212
# FOLD: 1, EPOCH: 15, valid_loss: 0.016431510954030924
# FOLD: 1, EPOCH: 16, train_loss: 0.016051223224865786
# FOLD: 1, EPOCH: 16, valid_loss: 0.016285996644624642
# FOLD: 1, EPOCH: 17, train_loss: 0.01577082897900887
# FOLD: 1, EPOCH: 17, valid_loss: 0.016149502966020787
# FOLD: 1, EPOCH: 18, train_loss: 0.015525321840592052
# FOLD: 1, EPOCH: 18, valid_loss: 0.016150739922055176
# FOLD: 1, EPOCH: 19, train_loss: 0.01512636157238613
# FOLD: 1, EPOCH: 19, valid_loss: 0.01592714350138392
# FOLD: 1, EPOCH: 20, train_loss: 0.01461090130623484
# FOLD: 1, EPOCH: 20, valid_loss: 0.015779834559985568
# FOLD: 1, EPOCH: 21, train_loss: 0.014147958738486404
# FOLD: 1, EPOCH: 21, valid_loss: 0.01557370325816529
# FOLD: 1, EPOCH: 22, train_loss: 0.013543335963850435
# FOLD: 1, EPOCH: 22, valid_loss: 0.0155764869547316
# FOLD: 1, EPOCH: 23, train_loss: 0.013060882140922806
# FOLD: 1, EPOCH: 23, valid_loss: 0.015534343703516891
# FOLD: 1, EPOCH: 24, train_loss: 0.012812267664981924
# FOLD: 1, EPOCH: 24, valid_loss: 0.015534295540835177
# FOLD: 2, EPOCH: 0, train_loss: 0.46874713352408964
# FOLD: 2, EPOCH: 0, valid_loss: 0.029690021915095195
# FOLD: 2, EPOCH: 1, train_loss: 0.02066802665375281
# FOLD: 2, EPOCH: 1, valid_loss: 0.01855957814093147
# FOLD: 2, EPOCH: 2, train_loss: 0.018111153377516977
# FOLD: 2, EPOCH: 2, valid_loss: 0.01765597364200013
# FOLD: 2, EPOCH: 3, train_loss: 0.01747917657232155
# FOLD: 2, EPOCH: 3, valid_loss: 0.01755468605884484
# FOLD: 2, EPOCH: 4, train_loss: 0.01710003210177672
# FOLD: 2, EPOCH: 4, valid_loss: 0.017625159504158158
# FOLD: 2, EPOCH: 5, train_loss: 0.01697606711472938
# FOLD: 2, EPOCH: 5, valid_loss: 0.017506776244512627
# FOLD: 2, EPOCH: 6, train_loss: 0.01698517109658839
# FOLD: 2, EPOCH: 6, valid_loss: 0.017280276439019613
# FOLD: 2, EPOCH: 7, train_loss: 0.016983940009621605
# FOLD: 2, EPOCH: 7, valid_loss: 0.017602869495749473
# FOLD: 2, EPOCH: 8, train_loss: 0.016902781071384317
# FOLD: 2, EPOCH: 8, valid_loss: 0.01720220252339329
# FOLD: 2, EPOCH: 9, train_loss: 0.01695521368874588
# FOLD: 2, EPOCH: 9, valid_loss: 0.01748241830085005
# FOLD: 2, EPOCH: 10, train_loss: 0.0169171665498204
# FOLD: 2, EPOCH: 10, valid_loss: 0.017082240538937705
# FOLD: 2, EPOCH: 11, train_loss: 0.016773047357581665
# FOLD: 2, EPOCH: 11, valid_loss: 0.017000731107379707
# FOLD: 2, EPOCH: 12, train_loss: 0.016690798286024645
# FOLD: 2, EPOCH: 12, valid_loss: 0.016937596324299063
# FOLD: 2, EPOCH: 13, train_loss: 0.01660440874326488
# FOLD: 2, EPOCH: 13, valid_loss: 0.016946404054760934
# FOLD: 2, EPOCH: 14, train_loss: 0.01646438751882617
# FOLD: 2, EPOCH: 14, valid_loss: 0.016960945964923927
# FOLD: 2, EPOCH: 15, train_loss: 0.016267512472805338
# FOLD: 2, EPOCH: 15, valid_loss: 0.01644360651927335
# FOLD: 2, EPOCH: 16, train_loss: 0.01604023693210405
# FOLD: 2, EPOCH: 16, valid_loss: 0.01639583831919091
# FOLD: 2, EPOCH: 17, train_loss: 0.01578761517083731
# FOLD: 2, EPOCH: 17, valid_loss: 0.016270715610257218
# FOLD: 2, EPOCH: 18, train_loss: 0.015487034940093325
# FOLD: 2, EPOCH: 18, valid_loss: 0.016116583852895668
# FOLD: 2, EPOCH: 19, train_loss: 0.015035466932138239
# FOLD: 2, EPOCH: 19, valid_loss: 0.015916101900594577
# FOLD: 2, EPOCH: 20, train_loss: 0.014598620346868816
# FOLD: 2, EPOCH: 20, valid_loss: 0.01575813681951591
# FOLD: 2, EPOCH: 21, train_loss: 0.014050328759881466
# FOLD: 2, EPOCH: 21, valid_loss: 0.015596428194216319
# FOLD: 2, EPOCH: 22, train_loss: 0.013424291579133791
# FOLD: 2, EPOCH: 22, valid_loss: 0.015542802241231715
# FOLD: 2, EPOCH: 23, train_loss: 0.012924835929458124
# FOLD: 2, EPOCH: 23, valid_loss: 0.015496201866439411
# FOLD: 2, EPOCH: 24, train_loss: 0.012668641088395447
# FOLD: 2, EPOCH: 24, valid_loss: 0.015504117948668343
# FOLD: 3, EPOCH: 0, train_loss: 0.4670411738283608
# FOLD: 3, EPOCH: 0, valid_loss: 0.02424856083733695
# FOLD: 3, EPOCH: 1, train_loss: 0.02049746514176545
# FOLD: 3, EPOCH: 1, valid_loss: 0.01898681739611285
# FOLD: 3, EPOCH: 2, train_loss: 0.01839744093814406
# FOLD: 3, EPOCH: 2, valid_loss: 0.01798019680593695
# FOLD: 3, EPOCH: 3, train_loss: 0.017427230732974367
# FOLD: 3, EPOCH: 3, valid_loss: 0.017515097425452302
# FOLD: 3, EPOCH: 4, train_loss: 0.017084201541391834
# FOLD: 3, EPOCH: 4, valid_loss: 0.01754472710724388
# FOLD: 3, EPOCH: 5, train_loss: 0.017073347078015406
# FOLD: 3, EPOCH: 5, valid_loss: 0.017713725620082447
# FOLD: 3, EPOCH: 6, train_loss: 0.017042929846523464
# FOLD: 3, EPOCH: 6, valid_loss: 0.017615669114249093
# FOLD: 3, EPOCH: 7, train_loss: 0.016991232299124418
# FOLD: 3, EPOCH: 7, valid_loss: 0.01762276693646397
# FOLD: 3, EPOCH: 8, train_loss: 0.016949118945099737
# FOLD: 3, EPOCH: 8, valid_loss: 0.017522478901914187
# FOLD: 3, EPOCH: 9, train_loss: 0.01694956085091268
# FOLD: 3, EPOCH: 9, valid_loss: 0.017530615122190545
# FOLD: 3, EPOCH: 10, train_loss: 0.01688775435710947
# FOLD: 3, EPOCH: 10, valid_loss: 0.017233095956700188
# FOLD: 3, EPOCH: 11, train_loss: 0.01680487349791371
# FOLD: 3, EPOCH: 11, valid_loss: 0.017344641446002892
# FOLD: 3, EPOCH: 12, train_loss: 0.01676437055584097
# FOLD: 3, EPOCH: 12, valid_loss: 0.017232265882194044
# FOLD: 3, EPOCH: 13, train_loss: 0.01665475853867289
# FOLD: 3, EPOCH: 13, valid_loss: 0.017330882272550037
# FOLD: 3, EPOCH: 14, train_loss: 0.016420348932075758
# FOLD: 3, EPOCH: 14, valid_loss: 0.016815387856747424
# FOLD: 3, EPOCH: 15, train_loss: 0.016287883844874475
# FOLD: 3, EPOCH: 15, valid_loss: 0.01670273912272283
# FOLD: 3, EPOCH: 16, train_loss: 0.016103800372692986
# FOLD: 3, EPOCH: 16, valid_loss: 0.016470124678952352
# FOLD: 3, EPOCH: 17, train_loss: 0.015787547609458368
# FOLD: 3, EPOCH: 17, valid_loss: 0.016283830468143735
# FOLD: 3, EPOCH: 18, train_loss: 0.015500400046669487
# FOLD: 3, EPOCH: 18, valid_loss: 0.016295131934540612
# FOLD: 3, EPOCH: 19, train_loss: 0.015119486009243174
# FOLD: 3, EPOCH: 19, valid_loss: 0.016003128354038512
# FOLD: 3, EPOCH: 20, train_loss: 0.014673512786680805
# FOLD: 3, EPOCH: 20, valid_loss: 0.0157994575000235
# FOLD: 3, EPOCH: 21, train_loss: 0.014158193298709997
# FOLD: 3, EPOCH: 21, valid_loss: 0.015763302360262188
# FOLD: 3, EPOCH: 22, train_loss: 0.013603389141676218
# FOLD: 3, EPOCH: 22, valid_loss: 0.01565256629671369
# FOLD: 3, EPOCH: 23, train_loss: 0.013114176042701887
# FOLD: 3, EPOCH: 23, valid_loss: 0.015607023744710855
# FOLD: 3, EPOCH: 24, train_loss: 0.012877855308191933
# FOLD: 3, EPOCH: 24, valid_loss: 0.0156107952019998
# FOLD: 4, EPOCH: 0, train_loss: 0.4691265417343896
# FOLD: 4, EPOCH: 0, valid_loss: 0.024299341014453343
# FOLD: 4, EPOCH: 1, train_loss: 0.0204457287285207
# FOLD: 4, EPOCH: 1, valid_loss: 0.01888825563447816
# FOLD: 4, EPOCH: 2, train_loss: 0.018267723947655464
# FOLD: 4, EPOCH: 2, valid_loss: 0.017776817828416825
# FOLD: 4, EPOCH: 3, train_loss: 0.017468646728852087
# FOLD: 4, EPOCH: 3, valid_loss: 0.017433091066777706
# FOLD: 4, EPOCH: 4, train_loss: 0.017106914460874985
# FOLD: 4, EPOCH: 4, valid_loss: 0.01754930330706494
# FOLD: 4, EPOCH: 5, train_loss: 0.016964728809029297
# FOLD: 4, EPOCH: 5, valid_loss: 0.017343876963215214
# FOLD: 4, EPOCH: 6, train_loss: 0.016916944841057924
# FOLD: 4, EPOCH: 6, valid_loss: 0.017274351896984237
# FOLD: 4, EPOCH: 7, train_loss: 0.016948529667612434
# FOLD: 4, EPOCH: 7, valid_loss: 0.01736976738486971
# FOLD: 4, EPOCH: 8, train_loss: 0.01688602920351685
# FOLD: 4, EPOCH: 8, valid_loss: 0.01730821853769677
# FOLD: 4, EPOCH: 9, train_loss: 0.01690869044134582
# FOLD: 4, EPOCH: 9, valid_loss: 0.017212771624326707
# FOLD: 4, EPOCH: 10, train_loss: 0.016865799412725195
# FOLD: 4, EPOCH: 10, valid_loss: 0.01723030230828694
# FOLD: 4, EPOCH: 11, train_loss: 0.01680376146501605
# FOLD: 4, EPOCH: 11, valid_loss: 0.017113567808909075
# FOLD: 4, EPOCH: 12, train_loss: 0.016676101860576782
# FOLD: 4, EPOCH: 12, valid_loss: 0.016896751203707285
# FOLD: 4, EPOCH: 13, train_loss: 0.016530597609454308
# FOLD: 4, EPOCH: 13, valid_loss: 0.017093790056450026
# FOLD: 4, EPOCH: 14, train_loss: 0.016410522345129564
# FOLD: 4, EPOCH: 14, valid_loss: 0.016768483445048332
# FOLD: 4, EPOCH: 15, train_loss: 0.016255141789282578
# FOLD: 4, EPOCH: 15, valid_loss: 0.016378994738417012
# FOLD: 4, EPOCH: 16, train_loss: 0.01601981990498261
# FOLD: 4, EPOCH: 16, valid_loss: 0.016446848107235772
# FOLD: 4, EPOCH: 17, train_loss: 0.0157139728696126
# FOLD: 4, EPOCH: 17, valid_loss: 0.0162067178104605
# FOLD: 4, EPOCH: 18, train_loss: 0.015472357255825098
# FOLD: 4, EPOCH: 18, valid_loss: 0.01606142209576709
# FOLD: 4, EPOCH: 19, train_loss: 0.015076153945393753
# FOLD: 4, EPOCH: 19, valid_loss: 0.015872590110770295
# FOLD: 4, EPOCH: 20, train_loss: 0.014558710866486248
# FOLD: 4, EPOCH: 20, valid_loss: 0.01574520958321435
# FOLD: 4, EPOCH: 21, train_loss: 0.014029401442224997
# FOLD: 4, EPOCH: 21, valid_loss: 0.015603831623281751
# FOLD: 4, EPOCH: 22, train_loss: 0.013414398881782225
# FOLD: 4, EPOCH: 22, valid_loss: 0.015468239491539342
# FOLD: 4, EPOCH: 23, train_loss: 0.012942667375656141
# FOLD: 4, EPOCH: 23, valid_loss: 0.015442756776298796
# FOLD: 4, EPOCH: 24, train_loss: 0.0126331417105984
# FOLD: 4, EPOCH: 24, valid_loss: 0.015457863679953984
# FOLD: 0, EPOCH: 0, train_loss: 0.46682299917860737
# FOLD: 0, EPOCH: 0, valid_loss: 0.024231300875544547
# FOLD: 0, EPOCH: 1, train_loss: 0.02072396861605238
# FOLD: 0, EPOCH: 1, valid_loss: 0.018543400189706256
# FOLD: 0, EPOCH: 2, train_loss: 0.018212848039262968
# FOLD: 0, EPOCH: 2, valid_loss: 0.017511057587606568
# FOLD: 0, EPOCH: 3, train_loss: 0.017414558476404003
# FOLD: 0, EPOCH: 3, valid_loss: 0.01743797015930925
# FOLD: 0, EPOCH: 4, train_loss: 0.01707841405995946
# FOLD: 0, EPOCH: 4, valid_loss: 0.017316708953252862
# FOLD: 0, EPOCH: 5, train_loss: 0.017001496513198683
# FOLD: 0, EPOCH: 5, valid_loss: 0.017451937017696244
# FOLD: 0, EPOCH: 6, train_loss: 0.017205287898094324
# FOLD: 0, EPOCH: 6, valid_loss: 0.017179016928587643
# FOLD: 0, EPOCH: 7, train_loss: 0.01710348921166598
# FOLD: 0, EPOCH: 7, valid_loss: 0.01737724186054298
# FOLD: 0, EPOCH: 8, train_loss: 0.01702309642796931
# FOLD: 0, EPOCH: 8, valid_loss: 0.01710996271244117
# FOLD: 0, EPOCH: 9, train_loss: 0.016912135579015896
# FOLD: 0, EPOCH: 9, valid_loss: 0.017090912722051144
# FOLD: 0, EPOCH: 10, train_loss: 0.016915232246822638
# FOLD: 0, EPOCH: 10, valid_loss: 0.016793765207486492
# FOLD: 0, EPOCH: 11, train_loss: 0.01687580745910173
# FOLD: 0, EPOCH: 11, valid_loss: 0.016849217723522866
# FOLD: 0, EPOCH: 12, train_loss: 0.016784464468018734
# FOLD: 0, EPOCH: 12, valid_loss: 0.01676238240408046
# FOLD: 0, EPOCH: 13, train_loss: 0.01655384555351043
# FOLD: 0, EPOCH: 13, valid_loss: 0.016933373494872023
# FOLD: 0, EPOCH: 14, train_loss: 0.016555730098237593
# FOLD: 0, EPOCH: 14, valid_loss: 0.01657698835645403
# FOLD: 0, EPOCH: 15, train_loss: 0.016253244037321514
# FOLD: 0, EPOCH: 15, valid_loss: 0.016443449977253166
# FOLD: 0, EPOCH: 16, train_loss: 0.016122334036112265
# FOLD: 0, EPOCH: 16, valid_loss: 0.01648271336619343
# FOLD: 0, EPOCH: 17, train_loss: 0.015804855031487736
# FOLD: 0, EPOCH: 17, valid_loss: 0.016089349931904248
# FOLD: 0, EPOCH: 18, train_loss: 0.015482322137424911
# FOLD: 0, EPOCH: 18, valid_loss: 0.016149459326905865
# FOLD: 0, EPOCH: 19, train_loss: 0.015096103806264591
# FOLD: 0, EPOCH: 19, valid_loss: 0.015753648110798428
# FOLD: 0, EPOCH: 20, train_loss: 0.014587081833810045
# FOLD: 0, EPOCH: 20, valid_loss: 0.015725809867892945
# FOLD: 0, EPOCH: 21, train_loss: 0.014027322318566881
# FOLD: 0, EPOCH: 21, valid_loss: 0.015541661530733109
# FOLD: 0, EPOCH: 22, train_loss: 0.013396053338774305
# FOLD: 0, EPOCH: 22, valid_loss: 0.015483515150845052
# FOLD: 0, EPOCH: 23, train_loss: 0.012870513732828524
# FOLD: 0, EPOCH: 23, valid_loss: 0.01542521920055151
# FOLD: 0, EPOCH: 24, train_loss: 0.012604173819493988
# FOLD: 0, EPOCH: 24, valid_loss: 0.015439911213304316
# FOLD: 1, EPOCH: 0, train_loss: 0.4681240551146692
# FOLD: 1, EPOCH: 0, valid_loss: 0.023382785437362535
# FOLD: 1, EPOCH: 1, train_loss: 0.020835764125745365
# FOLD: 1, EPOCH: 1, valid_loss: 0.01908313717160906
# FOLD: 1, EPOCH: 2, train_loss: 0.018429680794909382
# FOLD: 1, EPOCH: 2, valid_loss: 0.017505939970059056
# FOLD: 1, EPOCH: 3, train_loss: 0.017481487332100885
# FOLD: 1, EPOCH: 3, valid_loss: 0.017548554576933384
# FOLD: 1, EPOCH: 4, train_loss: 0.017075446818995733
# FOLD: 1, EPOCH: 4, valid_loss: 0.017356115127248422
# FOLD: 1, EPOCH: 5, train_loss: 0.016998513075320618
# FOLD: 1, EPOCH: 5, valid_loss: 0.017150147206016948
# FOLD: 1, EPOCH: 6, train_loss: 0.01696076341972187
# FOLD: 1, EPOCH: 6, valid_loss: 0.01715125712965216
# FOLD: 1, EPOCH: 7, train_loss: 0.01700627153226431
# FOLD: 1, EPOCH: 7, valid_loss: 0.016973376380545753
# FOLD: 1, EPOCH: 8, train_loss: 0.01705096807816754
# FOLD: 1, EPOCH: 8, valid_loss: 0.017276894487440585
# FOLD: 1, EPOCH: 9, train_loss: 0.016924430845656258
# FOLD: 1, EPOCH: 9, valid_loss: 0.017571935376950672
# FOLD: 1, EPOCH: 10, train_loss: 0.016909790454783302
# FOLD: 1, EPOCH: 10, valid_loss: 0.01717558495168175
# FOLD: 1, EPOCH: 11, train_loss: 0.016815381947958816
# FOLD: 1, EPOCH: 11, valid_loss: 0.01697488616087607
# FOLD: 1, EPOCH: 12, train_loss: 0.0167686071894739
# FOLD: 1, EPOCH: 12, valid_loss: 0.016638090195400374
# FOLD: 1, EPOCH: 13, train_loss: 0.016543819380087265
# FOLD: 1, EPOCH: 13, valid_loss: 0.017293897617076125
# FOLD: 1, EPOCH: 14, train_loss: 0.016506480660451496
# FOLD: 1, EPOCH: 14, valid_loss: 0.016792315005191735
# FOLD: 1, EPOCH: 15, train_loss: 0.016363835481899805
# FOLD: 1, EPOCH: 15, valid_loss: 0.01668481837425913
# FOLD: 1, EPOCH: 16, train_loss: 0.016088063430472994
# FOLD: 1, EPOCH: 16, valid_loss: 0.016334038094750473
# FOLD: 1, EPOCH: 17, train_loss: 0.015801829913550097
# FOLD: 1, EPOCH: 17, valid_loss: 0.016275794085647378
# FOLD: 1, EPOCH: 18, train_loss: 0.01547500358192601
# FOLD: 1, EPOCH: 18, valid_loss: 0.016026532064591134
# FOLD: 1, EPOCH: 19, train_loss: 0.015081515090297098
# FOLD: 1, EPOCH: 19, valid_loss: 0.01582426649651357
# FOLD: 1, EPOCH: 20, train_loss: 0.014576482019670631
# FOLD: 1, EPOCH: 20, valid_loss: 0.01579460988619498
# FOLD: 1, EPOCH: 21, train_loss: 0.014046601856640284
# FOLD: 1, EPOCH: 21, valid_loss: 0.015611420518585615
# FOLD: 1, EPOCH: 22, train_loss: 0.013405998696343622
# FOLD: 1, EPOCH: 22, valid_loss: 0.015566763335040637
# FOLD: 1, EPOCH: 23, train_loss: 0.012933382001853939
# FOLD: 1, EPOCH: 23, valid_loss: 0.01553934844476836
# FOLD: 1, EPOCH: 24, train_loss: 0.012665747570386831
# FOLD: 1, EPOCH: 24, valid_loss: 0.015537089774651187
# FOLD: 2, EPOCH: 0, train_loss: 0.46792216607086035
# FOLD: 2, EPOCH: 0, valid_loss: 0.025513120793870518
# FOLD: 2, EPOCH: 1, train_loss: 0.020567349941078304
# FOLD: 2, EPOCH: 1, valid_loss: 0.02016815793301378
# FOLD: 2, EPOCH: 2, train_loss: 0.018356226938034313
# FOLD: 2, EPOCH: 2, valid_loss: 0.017637837066182067
# FOLD: 2, EPOCH: 3, train_loss: 0.017514128001757723
# FOLD: 2, EPOCH: 3, valid_loss: 0.017777367308735848
# FOLD: 2, EPOCH: 4, train_loss: 0.017187974476457937
# FOLD: 2, EPOCH: 4, valid_loss: 0.017566808047039167
# FOLD: 2, EPOCH: 5, train_loss: 0.017065737882386082
# FOLD: 2, EPOCH: 5, valid_loss: 0.017334212682076862
# FOLD: 2, EPOCH: 6, train_loss: 0.016955265728081915
# FOLD: 2, EPOCH: 6, valid_loss: 0.017633918965501445
# FOLD: 2, EPOCH: 7, train_loss: 0.01695854527929771
# FOLD: 2, EPOCH: 7, valid_loss: 0.017341500015131066
# FOLD: 2, EPOCH: 8, train_loss: 0.016989154639937307
# FOLD: 2, EPOCH: 8, valid_loss: 0.017282759797360214
# FOLD: 2, EPOCH: 9, train_loss: 0.01694133153617166
# FOLD: 2, EPOCH: 9, valid_loss: 0.017312374444944517
# FOLD: 2, EPOCH: 10, train_loss: 0.01688381872963214
# FOLD: 2, EPOCH: 10, valid_loss: 0.01704621557146311
# FOLD: 2, EPOCH: 11, train_loss: 0.01683766789653379
# FOLD: 2, EPOCH: 11, valid_loss: 0.01693402568676642
# FOLD: 2, EPOCH: 12, train_loss: 0.016693404848700848
# FOLD: 2, EPOCH: 12, valid_loss: 0.017219743877649307
# FOLD: 2, EPOCH: 13, train_loss: 0.016553300324881424
# FOLD: 2, EPOCH: 13, valid_loss: 0.016985091620257922
# FOLD: 2, EPOCH: 14, train_loss: 0.016487583787976833
# FOLD: 2, EPOCH: 14, valid_loss: 0.01669059872095074
# FOLD: 2, EPOCH: 15, train_loss: 0.01627351288292287
# FOLD: 2, EPOCH: 15, valid_loss: 0.016690434222774848
# FOLD: 2, EPOCH: 16, train_loss: 0.016114973112184933
# FOLD: 2, EPOCH: 16, valid_loss: 0.016537433516766342
# FOLD: 2, EPOCH: 17, train_loss: 0.01578164423910388
# FOLD: 2, EPOCH: 17, valid_loss: 0.016267598500209195
# FOLD: 2, EPOCH: 18, train_loss: 0.015539314550604078
# FOLD: 2, EPOCH: 18, valid_loss: 0.01604195029607841
# FOLD: 2, EPOCH: 19, train_loss: 0.015057969642668098
# FOLD: 2, EPOCH: 19, valid_loss: 0.015931142387645585
# FOLD: 2, EPOCH: 20, train_loss: 0.014585244685303474
# FOLD: 2, EPOCH: 20, valid_loss: 0.015812673632587704
# FOLD: 2, EPOCH: 21, train_loss: 0.014075559752898804
# FOLD: 2, EPOCH: 21, valid_loss: 0.015714545947100436
# FOLD: 2, EPOCH: 22, train_loss: 0.013481826521456242
# FOLD: 2, EPOCH: 22, valid_loss: 0.01559901660574334
# FOLD: 2, EPOCH: 23, train_loss: 0.013000012031229942
# FOLD: 2, EPOCH: 23, valid_loss: 0.015585903557283537
# FOLD: 2, EPOCH: 24, train_loss: 0.012763387894770805
# FOLD: 2, EPOCH: 24, valid_loss: 0.015577340844486441
# FOLD: 3, EPOCH: 0, train_loss: 0.4674996852442838
# FOLD: 3, EPOCH: 0, valid_loss: 0.023850528044360025
# FOLD: 3, EPOCH: 1, train_loss: 0.020341598604252373
# FOLD: 3, EPOCH: 1, valid_loss: 0.01873219135616507
# FOLD: 3, EPOCH: 2, train_loss: 0.018210391075336847
# FOLD: 3, EPOCH: 2, valid_loss: 0.017849263921380042
# FOLD: 3, EPOCH: 3, train_loss: 0.01744300988165365
# FOLD: 3, EPOCH: 3, valid_loss: 0.017534072537507328
# FOLD: 3, EPOCH: 4, train_loss: 0.016993986692387556
# FOLD: 3, EPOCH: 4, valid_loss: 0.017460823245346545
# FOLD: 3, EPOCH: 5, train_loss: 0.01696722339703769
# FOLD: 3, EPOCH: 5, valid_loss: 0.017424022539385728
# FOLD: 3, EPOCH: 6, train_loss: 0.016955800172265455
# FOLD: 3, EPOCH: 6, valid_loss: 0.017191845790616105
# FOLD: 3, EPOCH: 7, train_loss: 0.017013837374152914
# FOLD: 3, EPOCH: 7, valid_loss: 0.017357496544718742
# FOLD: 3, EPOCH: 8, train_loss: 0.01696365614813091
# FOLD: 3, EPOCH: 8, valid_loss: 0.01720583053039653
# FOLD: 3, EPOCH: 9, train_loss: 0.01695293671977909
# FOLD: 3, EPOCH: 9, valid_loss: 0.01733075026422739
# FOLD: 3, EPOCH: 10, train_loss: 0.016883943601093
# FOLD: 3, EPOCH: 10, valid_loss: 0.016991269375596727
# FOLD: 3, EPOCH: 11, train_loss: 0.016776892774994823
# FOLD: 3, EPOCH: 11, valid_loss: 0.016894399667424814
# FOLD: 3, EPOCH: 12, train_loss: 0.01673786394783984
# FOLD: 3, EPOCH: 12, valid_loss: 0.016938676897968564
# FOLD: 3, EPOCH: 13, train_loss: 0.01658332958628518
# FOLD: 3, EPOCH: 13, valid_loss: 0.01688423843256065
# FOLD: 3, EPOCH: 14, train_loss: 0.016404580432867657
# FOLD: 3, EPOCH: 14, valid_loss: 0.016690278159720556
# FOLD: 3, EPOCH: 15, train_loss: 0.0162345875405531
# FOLD: 3, EPOCH: 15, valid_loss: 0.01653738905276571
# FOLD: 3, EPOCH: 16, train_loss: 0.015984920643108046
# FOLD: 3, EPOCH: 16, valid_loss: 0.016564358664410455
# FOLD: 3, EPOCH: 17, train_loss: 0.015749709761661033
# FOLD: 3, EPOCH: 17, valid_loss: 0.016311922589583056
# FOLD: 3, EPOCH: 18, train_loss: 0.015353957123622515
# FOLD: 3, EPOCH: 18, valid_loss: 0.016155734711459705
# FOLD: 3, EPOCH: 19, train_loss: 0.015024101604586062
# FOLD: 3, EPOCH: 19, valid_loss: 0.01596690828778914
# FOLD: 3, EPOCH: 20, train_loss: 0.014565989300878584
# FOLD: 3, EPOCH: 20, valid_loss: 0.015869427765054362
# FOLD: 3, EPOCH: 21, train_loss: 0.014001735249885183
# FOLD: 3, EPOCH: 21, valid_loss: 0.01569693365267345

# %%
train_targets_scored

# %%
len(target_cols)

# %%
valid_results = train_targets_scored.drop(columns=target_cols).merge(train.iloc[:-augmented_num,:][['sig_id']+target_cols], on='sig_id', how='left').fillna(0)


y_true = train_targets_scored[target_cols].values
y_pred = valid_results[target_cols].values

score = 0
for i in range(len(target_cols)):
    score_ = log_loss(y_true[:, i], y_pred[:, i])
    score += score_ / target.shape[1]
    
print("CV log_loss: ", score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87f226faa880> in <module>()
# ----> 1 valid_results = train_targets_scored.drop(columns=target_cols).merge(train.iloc[:-augmented_num,:][['sig_id']+target_cols], on='sig_id', how='left').fillna(0)
#       2
#       3
#       4 y_true = train_targets_scored[target_cols].values
#       5 y_pred = valid_results[target_cols].values
#
# NameError: name 'train_targets_scored' is not defined

# %%
sub = sample_submission.drop(columns=target_cols).merge(test[['sig_id']+target_cols], on='sig_id', how='left').fillna(0)
sub.to_csv('submission.csv', index=False)

# %%
sub.shape
